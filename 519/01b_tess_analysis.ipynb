# %% [markdown]
# # TOI 519.01 TESS light curve analysis

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %run core.py
# %run ../src/ctesslpf.py

# %%
lpf = CTESSLPF('toi_519_tess_cnt', tess_file, zero_epoch, period, bldur=0.15)

# %%
lpf.optimize_global(niter=15000, npop=150)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Global optimisation', max=15000.0, style=ProgressStyle(de…

# %%
lpf.plot_folded_transit(ylim=(0.8,1.1), binwidth=4)

# %%
lpf.sample_mcmc(repeats=50)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='MCMC sampling', max=50.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='Run 1/50', max=500.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Run 2/50', max=500.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Run 3/50', max=500.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Run 4/50', max=500.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Run 5/50', max=500.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Run 6/50', max=500.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Run 7/50', max=500.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Run 8/50', max=500.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Run 9/50', max=500.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Run 10/50', max=500.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Run 11/50', max=500.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Run 12/50', max=500.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Run 13/50', max=500.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Run 14/50', max=500.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Run 15/50', max=500.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Run 16/50', max=500.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Run 17/50', max=500.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Run 18/50', max=500.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Run 19/50', max=500.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Run 20/50', max=500.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Run 21/50', max=500.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Run 22/50', max=500.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Run 23/50', max=500.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Run 24/50', max=500.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Run 25/50', max=500.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Run 26/50', max=500.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Run 27/50', max=500.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Run 28/50', max=500.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Run 29/50', max=500.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Run 30/50', max=500.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Run 31/50', max=500.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Run 32/50', max=500.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Run 33/50', max=500.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Run 34/50', max=500.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Run 35/50', max=500.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Run 36/50', max=500.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Run 37/50', max=500.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Run 38/50', max=500.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Run 39/50', max=500.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Run 40/50', max=500.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Run 41/50', max=500.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Run 42/50', max=500.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Run 43/50', max=500.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Run 44/50', max=500.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Run 45/50', max=500.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Run 46/50', max=500.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Run 47/50', max=500.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Run 48/50', max=500.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Run 49/50', max=500.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Run 50/50', max=500.0, style=ProgressStyle(description_wi…

# %%
df = lpf.posterior_samples()

# %%
df.rho.hist()

# %%
(1 - df.k_app / df.k_true).hist()

# %%
df.k_true.hist()

# %%
df.k_app.hist()

# %%
lpf.save()

# %% [markdown]
# ---
#
# <center> © 2020 Hannu Parviainen </center>

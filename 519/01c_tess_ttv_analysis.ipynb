# %% [markdown]
# # TOI 519.01 TESS TTV analysis
#
# Here we check the TESS-observed TOI 519.01 transits for TTVs. We don't expect to see any, but it doesn't hurt to check anyway ;)

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pyopencl as cl
from uncertainties import ufloat

from pytransit.lpf.tessoclttvlpf import TESSCLTTVLPF

# %%
# %run core.py

# %%
ctx = cl.create_some_context()
queue = cl.CommandQueue(ctx)

# %%
lpf = TESSCLTTVLPF('toi_519', tess_file, zero_epoch, period, bldur=0.15, ctx=ctx, queue=queue)

# %%
lpf.optimize_global(niter=15000, npop=300)

# %%
lpf.plot_transits()

# %%
lpf.sample_mcmc(repeats=20)
# Out:
# ...
# /Users/hannu/soft/anaconda/lib/python3.7/site-packages/emcee-3.0.0-py3.7.egg/emcee/ensemble.py:258: RuntimeWarning: Initial state is not linearly independent and it will not allow a full exploration of parameter space
# ...

# %%
lpf.plot_ttvs(fmt='min', figsize=(13,6));

# %% [markdown]
# ---
#
# <center>© 2020 Hannu Parviainen</center>
